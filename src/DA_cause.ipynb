# %% [markdown]
# # Import

# %%
import os

import numpy as np
import pandas as pd # 여기에 있으면 안됨. 함수화 필요
import matplotlib.pyplot as plt

from data_engineering.dataset.precendent.data_pipeline import Pipelines

# %%
import matplotlib.font_manager as fm
import matplotlib as mpl
font_path = './NanumGothicLight.otf'
fm.fontManager.addfont(font_path) 
mpl.rcParams['font.family'] = 'NanumGothicOTF'
mpl.rcParams['axes.unicode_minus'] = False



import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %% [markdown]
# # 목적

# %% [markdown]
# 사고원인이 기타인 경우 기타를 재분류 가능할 지 알아보기

# %% [markdown]
# # 데이터

# %%
path_train = "/workspace/Storage/hansoldeco3/Data/raw/train.csv"
train = pd.read_csv(path_train)
train = Pipelines.pipeline_3(train)

# %%
path_test = "/workspace/Storage/hansoldeco3/Data/raw/test.csv"
test = pd.read_csv(path_test)
test = Pipelines.pipeline_3(test)

# %% [markdown]
# # 분석

# %%
train[train['사고원인']=='기타'].shape
# Out:
# (6, 26)

# %%
test[test['사고원인']=='기타'].shape
# Out:
# (0, 25)

# %%
train[train['인적사고']=='기타'].shape
# Out:
# (1915, 26)

# %%
test[test['인적사고']=='기타'].shape
# Out:
# (46, 25)

# %%
cause = train[train['사고원인']=='기타']

# %%
hd = train[train['인적사고']=='기타']

# %%
cause
# Out:
#                            발생일시 시간대  계절 사고인지 시간  사고인지시차  근무종류  날씨    기온    습도  \
# ID
# TRAIN_16107 2021-02-10 11:20:00  아침  겨울     NaT     NaN  정규작업  흐림   5.0  20.0
# TRAIN_16706 2020-12-16 09:10:00  아침  겨울     NaT     NaN  정규작업  흐림   1.0  30.0
# TRAIN_17046 2020-11-17 13:30:00   낮  겨울     NaT     NaN  정규작업  맑음   7.0  30.0
# TRAIN_17516 2020-10-18 11:00:00  아침  가을     NaT     NaN  휴일근무  맑음  20.0  30.0
# TRAIN_19007 2020-06-18 15:25:00   낮  여름     NaT     NaN  정규작업  강우  18.0  80.0
# TRAIN_22480 2019-09-17 10:30:00  아침  가을     NaT     NaN  정규작업  흐림  26.0  42.0
#
#             공사종류_대분류 공사종류_중분류 공사종류_소분류       연면적   지상   지하    인적사고 물적사고  \
# ID
# TRAIN_16107       건축      건축물       공장  133824.0  4.0  0.0      기타   기타
# TRAIN_16706       건축      건축물       공장  133824.0  4.0  0.0    분류불능   없음
# TRAIN_17046       건축      건축물       공장  133824.0  4.0  0.0    분류불능   없음
# TRAIN_17516       건축      건축물       공장  133824.0  4.0  0.0  물체에 맞음   없음
# ...

# %%
train[(train['재발방지대책 및 향후조치계획'].str.contains('향후 조치 계획')) & (train['재발방지대책 및 향후조치계획'].str.contains('재발 방지'))]
# Out:
#                            발생일시 시간대  계절 사고인지 시간  사고인지시차  근무종류  날씨    기온    습도  \
# ID
# TRAIN_00002 2023-12-30 14:30:00   낮  겨울     NaT     NaN  정규작업  맑음  14.0  70.0
# TRAIN_00017 2023-12-29 12:00:00  아침  겨울     NaT     NaN  정규작업  맑음   1.0  60.0
# TRAIN_00042 2023-12-28 14:00:00   낮  겨울     NaT     NaN  정규작업  맑음   6.0  60.0
# TRAIN_00048 2023-12-28 10:00:00  아침  겨울     NaT     NaN  정규작업  맑음   5.0  61.0
# TRAIN_00072 2023-12-27 08:00:00  아침  겨울     NaT     NaN  정규작업  맑음   8.0  30.0
# ...                         ...  ..  ..     ...     ...   ...  ..   ...   ...
# TRAIN_23367 2019-07-06 14:42:00   낮  여름     NaT     NaN   NaN  맑음  30.0  60.0
# TRAIN_23368 2019-07-06 14:00:00   낮  여름     NaT     NaN   NaN  흐림  29.0  41.0
# TRAIN_23387 2019-07-05 11:40:00  아침  여름     NaT     NaN   NaN  강우  33.0  93.0
# TRAIN_23408 2019-07-04 09:00:00  아침  여름     NaT     NaN   NaN  흐림  25.0  40.0
# TRAIN_23414 2019-07-03 16:00:00   낮  여름     NaT     NaN   NaN  맑음  23.0  70.0
#
# ...

# %%
for col in hd.columns:
    print(col, hd[col].value_counts().max()/len(hd)*100)
# Out:
# 발생일시 0.1566579634464752
# 시간대 51.54046997389033
# 계절 33.94255874673629
# 사고인지 시간 0.05221932114882506
# 사고인지시차 0.20887728459530025
# 근무종류 65.74412532637076
# 날씨 76.29242819843341
# 기온 5.274151436031332
# 습도 11.070496083550914
# 공사종류_대분류 72.0626631853786
# 공사종류_중분류 72.0626631853786
# 공사종류_소분류 29.39947780678851
# 연면적 1.4099216710182767
# 지상 5.326370757180157
# 지하 16.29242819843342
# 인적사고 100.0
# 물적사고 80.78328981723237
# 공종_대분류 52.16710182767624
# 공종_소분류 27.258485639686686
# 사고객체_대분류 32.010443864229764
# 사고객체_소분류 28.929503916449086
# 작업프로세스 16.29242819843342
# 장소 12.845953002610965
# 부위2 29.712793733681465
# 사고원인 0.9921671018276762
# 재발방지대책 및 향후조치계획 0.7832898172323759

# %%
for col in cause.columns:
    print(col, cause[col].value_counts().max()/len(cause)*100)
# Out:
# 발생일시 16.666666666666664
# 시간대 66.66666666666666
# 계절 50.0
# 사고인지 시간 nan
# 사고인지시차 nan
# 근무종류 83.33333333333334
# 날씨 50.0
# 기온 16.666666666666664
# 습도 50.0
# 공사종류_대분류 100.0
# 공사종류_중분류 100.0
# 공사종류_소분류 83.33333333333334
# 연면적 83.33333333333334
# 지상 83.33333333333334
# 지하 100.0
# 인적사고 50.0
# 물적사고 83.33333333333334
# 공종_대분류 50.0
# 공종_소분류 50.0
# 사고객체_대분류 66.66666666666666
# 사고객체_소분류 50.0
# 작업프로세스 50.0
# 장소 50.0
# 부위2 50.0
# 사고원인 100.0
# 재발방지대책 및 향후조치계획 50.0

# %%
cause
# Out:
#                            발생일시 시간대  계절 사고인지 시간  사고인지시차  근무종류  날씨    기온    습도  \
# ID
# TRAIN_16107 2021-02-10 11:20:00  아침  겨울     NaT     NaN  정규작업  흐림   5.0  20.0
# TRAIN_16706 2020-12-16 09:10:00  아침  겨울     NaT     NaN  정규작업  흐림   1.0  30.0
# TRAIN_17046 2020-11-17 13:30:00   낮  겨울     NaT     NaN  정규작업  맑음   7.0  30.0
# TRAIN_17516 2020-10-18 11:00:00  아침  가을     NaT     NaN  휴일근무  맑음  20.0  30.0
# TRAIN_19007 2020-06-18 15:25:00   낮  여름     NaT     NaN  정규작업  강우  18.0  80.0
# TRAIN_22480 2019-09-17 10:30:00  아침  가을     NaT     NaN  정규작업  흐림  26.0  42.0
#
#             공사종류_대분류 공사종류_중분류 공사종류_소분류       연면적   지상   지하    인적사고 물적사고  \
# ID
# TRAIN_16107       건축      건축물       공장  133824.0  4.0  0.0      기타   기타
# TRAIN_16706       건축      건축물       공장  133824.0  4.0  0.0    분류불능   없음
# TRAIN_17046       건축      건축물       공장  133824.0  4.0  0.0    분류불능   없음
# TRAIN_17516       건축      건축물       공장  133824.0  4.0  0.0  물체에 맞음   없음
# ...

# %%
hd[hd['사고원인'].fillna('').str.contains('부주의')]
# Out:
#                            발생일시   시간대  계절 사고인지 시간  사고인지시차  근무종류  날씨    기온  \
# ID
# TRAIN_00098 2023-12-26 07:50:00    아침  겨울     NaT     NaN  작업 전  맑음   3.0
# TRAIN_00170 2023-12-20 19:27:00    저녘  겨울     NaT     NaN    기타  맑음  -9.0
# TRAIN_00533 2023-11-28 16:00:00     낮  겨울     NaT     NaN  정규작업  맑음   4.0
# TRAIN_00577 2023-11-26 14:00:00     낮  겨울     NaT     NaN  휴일근무  맑음   8.0
# TRAIN_00583 2023-11-25 15:00:00     낮  겨울     NaT     NaN  정규작업  맑음 -12.0
# ...                         ...   ...  ..     ...     ...   ...  ..   ...
# TRAIN_23012 2019-08-02 14:00:00     낮  여름     NaT     NaN   NaN  맑음  32.0
# TRAIN_23072 2019-07-29 13:10:00     낮  여름     NaT     NaN  정규작업  안개  27.0
# TRAIN_23151 2019-07-23 00:20:00  <NA>  여름     NaT     NaN   NaN  맑음  23.0
# TRAIN_23353 2019-07-08 09:00:00    아침  여름     NaT     NaN   NaN  맑음  28.0
# TRAIN_23366 2019-07-06 14:48:00     낮  여름     NaT     NaN   NaN  맑음  33.6
#
# ...

# %%
hd['물적사고'].value_counts()
# Out:
# 물적사고
# 없음       1547
# 기타        115
# 전도         24
# 충돌          8
# 화재          5
# 폭발          3
# 파열,파단       3
# 낙하          1
# 붕괴          1
# Name: count, dtype: int64

# %%
hd['사고원인']
# Out:
# ID
# TRAIN_00003    교각 기초철근 조립 중 강한 바람에 의해 기둥측 주철근이 균형을 잃고 전도되어, 하...
# TRAIN_00013                  파이프를 밟고 미끄러지면서 발목과 발가락이 꺽이면서 발가락 골절
# TRAIN_00017    현장 내 조적 작업 진행 중 해당 작업자 허리에서 통증이 발생하였고, 병원 진료 등...
# TRAIN_00023    우레탄폼 사춤작업 준비 중 얼어있는 우레탄폼 케이스를 토치로 가열하다 케이스가 폭발...
# TRAIN_00028                             적절한 보안경 미착용, 보조원의 위치 부적절
#                                      ...
# TRAIN_23371    1층 기둥 유로폼 거푸짐 설치 중 본인 스스로 이동 중 유로품에 무릎을 부딪혀 재해 발생
# TRAIN_23381    경계석설치를 위하여 경계석 절단 작업 중 공도구(그라인더)가 멈춤. 이에따라 정비 ...
# TRAIN_23402                       타설작업 중 작업장 이동 중에 철근을 잘못 밟아 넘어짐
# TRAIN_23415                             반복된 자재 인력운반 작업으로 어깨통증 발생
# TRAIN_23420             지상2층 브레싱 홀 가공중 절단된 슬래그가 안전화 혀에 떨어져 화상 발생
# Name: 사고원인, Length: 1915, dtype: object

# %%
train['인적사고'].value_counts()
# Out:
# 인적사고
# 물체에 맞음                   3460
# 끼임                       2549
# 넘어짐(미끄러짐)                2188
# 넘어짐(기타)                  2063
# 기타                       1915
# 부딪힘                      1815
# 떨어짐(2미터 미만)              1735
# 절단, 베임                   1661
# 넘어짐(물체에 걸림)              1490
# 떨어짐(2미터 이상 ~ 3미터 미만)      759
# 떨어짐(분류불능)                 708
# 떨어짐(3미터 이상 ~ 5미터 미만)      545
# 깔림                        514
# 질병                        383
# 찔림                        306
# 떨어짐(5미터 이상 ~ 10미터 미만)     298
# 분류불능                      225
# 떨어짐(10미터 이상)              210
# 없음                        196
# 화상                        181
# 교통사고                      122
# 감전                         49
# 질식                         18
# Name: count, dtype: int64

# %%
train[train['인적사고'] =='물체에 맞음']
# Out:
#                            발생일시 시간대  계절             사고인지 시간  사고인지시차     근무종류  \
# ID
# TRAIN_00005 2023-12-30 10:00:00  아침  겨울                 NaT     NaN     정규작업
# TRAIN_00026 2023-12-29 09:40:00  아침  겨울                 NaT     NaN     정규작업
# TRAIN_00027 2023-12-29 09:30:00  아침  겨울                 NaT     NaN     정규작업
# TRAIN_00056 2023-12-28 07:50:00  아침  겨울                 NaT     NaN     정규작업
# TRAIN_00063 2023-12-27 14:00:00   낮  겨울                 NaT     NaN     정규작업
# ...                         ...  ..  ..                 ...     ...      ...
# TRAIN_23401 2019-07-04 13:40:00   낮  여름                 NaT     NaN     정규작업
# TRAIN_23403 2019-07-04 11:30:00  아침  여름 2019-07-04 13:00:00     1.5  식사ㆍ휴식 등
# TRAIN_23408 2019-07-04 09:00:00  아침  여름                 NaT     NaN      NaN
# TRAIN_23417 2019-07-03 15:10:00   낮  여름                 NaT     NaN      NaN
# TRAIN_23421 2019-07-03 14:30:00   낮  여름                 NaT     NaN     정규작업
#
# ...

# %%
train[train['인적사고'].isna()]
# Out:
#                            발생일시   시간대  계절 사고인지 시간  사고인지시차  근무종류  날씨    기온  \
# ID
# TRAIN_01051 2023-10-31 13:55:00     낮  가을     NaT     NaN  정규작업  맑음  24.0
# TRAIN_03188 2023-06-22 10:00:00    아침  여름     NaT     NaN  정규작업  강우  24.0
# TRAIN_05064 2023-03-16 14:10:00     낮   봄     NaT     NaN  정규작업  맑음   5.0
# TRAIN_09122 2022-06-21 15:30:00     낮  여름     NaT     NaN  정규작업  맑음   NaN
# TRAIN_15179 2021-04-21 08:00:00    아침   봄     NaT     NaN  정규작업  맑음   NaN
# TRAIN_15201 2021-04-20 09:50:00    아침   봄     NaT     NaN  정규작업  맑음  15.0
# TRAIN_16234 2021-01-29 15:55:00     낮  겨울     NaT     NaN  불류불능  맑음  -5.0
# TRAIN_16537 2020-12-30 09:36:00    아침  겨울     NaT     NaN  정규작업  맑음  -6.0
# TRAIN_18960 2020-06-22 19:26:00    저녘  여름     NaT     NaN   NaN  맑음  28.1
# TRAIN_18976 2020-06-21 15:50:00     낮  여름     NaT     NaN   NaN  맑음  32.3
# TRAIN_19220 2020-06-03 11:40:00    아침  여름     NaT     NaN   NaN  흐림  23.2
# TRAIN_19251 2020-06-02 08:56:00    아침  여름     NaT     NaN   NaN  흐림  16.0
# ...

# %% [markdown]
# # 결과

# %% [markdown]
# - 인적사고 기타값에서 사고원인에만 힌트가 존재하는데, 불규칙적이어서 처리 어려움.
# - 인적사고 nan값에 인적사고 있는 경우와 없는 경우 존재
